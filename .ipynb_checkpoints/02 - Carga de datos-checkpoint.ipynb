# %% [markdown]
# # Carga de modulos para tratamiento de datos

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
vuelos = sns.load_dataset('flights')
vuelos
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
pivoteVuelos = vuelos.pivot(index='month', columns='year', values='passengers')
pivoteVuelos
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# Dec     118   140   166   194   201   229   278   306   336   337   405   432

# %%
# sns.heatmap(datos, parametros)
mapa_calor = sns.heatmap(pivoteVuelos, annot=True, fmt='d')

# %% [markdown]
# # Carga de datos desde archivos

# %%
# desde pandas -> pd.read_tipo(ruta y nombre de archivo)
ruta_archivoX = 'datos.xlsx'
tabla = pd.read_excel(ruta_archivoX)
tabla
# Out:
#    Sexo  Peso  Talla  Edad
# 0     M   126    167    18
# 1     M   120    151    27
# 2     M   155    148    23
# 3     F   117    167    28
# 4     M   144    166    22
# 5     F   105    174    20
# 6     F   151    147    33
# 7     F   120    175    31
# 8     M   106    162    32
# 9     F   102    169    23
# 10    M   125    156    35
# 11    F   104    166    26
# 12    M   118    142    26
# 13    F   153    180    29
# 14    F   166    161    32
# 15    F   148    166    27
# 16    M   123    149    28
# 17    M   145    168    29
# 18    M   127    174    34
# 19    F   133    161    22
# 20    F   125    171    35
# 21    F   126    150    27
# 22    F   143    140    35
# 23    F   130    145    26
# 24    M   110    150    23
# 25    F   122    177    21
# 26    M   161    179    18
# 27    F   131    182    30
# 28    M   117    156    23
# 29    F   155    169    28
# 30    F   144    182    31
# 31    M   134    146    26
# 32    M   113    172    31
# 33    M   170    177    20
# 34    M   156    142    25
# 35    M   109    147    27
# 36    M   143    141    26
# 37    M   124    172    26
# 38    F   152    148    19
# 39    F   164    184    32

# %%
aapl = pd.read_csv('AAPL.csv')
aapl
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2020-11-02  109.110001  110.680000  107.320000  108.769997  107.780052
# 1    2020-11-03  109.660004  111.489998  108.730003  110.440002  109.434868
# 2    2020-11-04  114.139999  115.589996  112.349998  114.949997  113.903816
# 3    2020-11-05  117.949997  119.620003  116.870003  119.029999  117.946686
# 4    2020-11-06  118.320000  119.199997  116.129997  118.690002  117.812691
# ..          ...         ...         ...         ...         ...         ...
# 315  2022-02-02  174.750000  175.880005  173.330002  175.839996  175.616257
# 316  2022-02-03  174.479996  176.240005  172.119995  172.899994  172.679993
# 317  2022-02-04  171.679993  174.100006  170.679993  172.389999  172.389999
# 318  2022-02-07  172.860001  173.949997  170.949997  171.660004  171.660004
# 319  2022-02-08  171.729996  175.350006  171.429993  174.830002  174.830002
#
#         Volume
# 0    122866900
# 1    107624400
# 2    138235500
# 3    126387100
# 4    114457900
# ..         ...
# 315   84914300
# 316   89418100
# 317   82391400
# 318   77251200
# 319   74706900
#
# [320 rows x 7 columns]

# %%
##planilla = pd.read_clipboard(sep=',')
##planilla.to_csv('planilla.csv')
##planilla
planilla = pd.read_csv('planilla.csv')
planilla.set_index('codigo', inplace=True)
planilla
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5272\1072971798.py in ?()
#       1 ##planilla = pd.read_clipboard(sep=',')
#       2 ##planilla.to_csv('planilla.csv')
#       3 ##planilla
#       4 planilla = pd.read_csv('planilla.csv')
# ----> 5 planilla.set_index('codigo', inplace=True)
#       6 planilla
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['codigo'] are in the columns"

# %%
# recuenda de fila, columna
contingencia = pd.crosstab(tabla['Edad'], tabla['Sexo'])
contingencia
# Out:
# Sexo  F  M
# Edad
# 18    0  2
# 19    1  0
# 20    1  1
# 21    1  0
# 22    1  1
# 23    1  3
# 25    0  1
# 26    2  4
# 27    2  2
# 28    2  1
# 29    1  1
# 30    1  0
# 31    2  1
# 32    2  1
# 33    1  0
# 34    0  1
# 35    2  1

# %%
n = len(tabla)
intervalos = pd.cut(tabla['Edad'], bins=5)
frecuenciaGrupo = pd.crosstab(index= intervalos, columns='f')
tablaEdad = pd.DataFrame(frecuenciaGrupo.index)
tablaEdad['f'] = frecuenciaGrupo.values
tablaEdad['fa'] = tablaEdad['f'].cumsum()
tablaEdad['fr'] = tablaEdad['f']/n
tablaEdad['fra'] = tablaEdad['fr'].cumsum()
tablaEdad['%'] = tablaEdad['fr']*100
tablaEdad['%a'] = tablaEdad['fra']*100
tablaEdad
# Out:
#              Edad   f  fa    fr   fra     %     %a
# 0  (17.983, 21.4]   6   6  0.15  0.15  15.0   15.0
# 1    (21.4, 24.8]   6  12  0.15  0.30  15.0   30.0
# 2    (24.8, 28.2]  14  26  0.35  0.65  35.0   65.0
# 3    (28.2, 31.6]   6  32  0.15  0.80  15.0   80.0
# 4    (31.6, 35.0]   8  40  0.20  1.00  20.0  100.0
